# %% [markdown]
# <a href="https://colab.research.google.com/github/techut30/MachineLearning-Assignment-2/blob/main/ML_assignment_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

X = pd.read_csv('logisticX.csv')
y = pd.read_csv('logisticY.csv')

X = X.values
y = y.values.flatten()

plt.figure(figsize=(10, 6))

for i in range(len(y)):
    if y[i] == 0:
        plt.plot(X[i, 0], X[i, 1], 'ro')

for i in range(len(y)):
    if y[i] == 1:
        plt.plot(X[i, 0], X[i, 1], 'bo')

x_values = np.array([np.min(X[:, 0]), np.max(X[:, 0])])
y_values = -(theta[0] + theta[1] * x_values) / theta[2]
plt.plot(x_values, y_values, 'g-', label='Decision Boundary')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Dataset with Decision Boundary')
plt.legend()
plt.show()
